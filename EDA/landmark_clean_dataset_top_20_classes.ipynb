# %% [markdown]
# <a href="https://colab.research.google.com/github/elpeme/w281_final_project/blob/main/W281_Landmark_clean_dataset_top_20_classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from PIL import Image
import PIL
import matplotlib
import matplotlib.pyplot as plt
import urllib.request
from io import BytesIO

import requests

import json
from matplotlib import image as mpimg
import cv2
import pickle

# %%
from google.colab import drive
drive.mount('/content/drive')

# Load dataframes from pickle file 


""" There are 3 pickle files in the Drive folder. Each file is a pandas dataframe that includes columns: ['id', 'landmark_id', 'category', 'tiny_image']
"tiny_image" column is the image as nparray

- filename: "top_20_df_w_images_arrays.pkl" includes the top 20 classes size: 1.86GB
- filename: "top_10_df_w_images_arrays.pkl" includes the top 10 classes size: 1.02GB 
- filename: "top_11_to_20_df_w_images_arrays.pkl" includes 11 to 20 top classes size: 861MB

Use load_dataset function to load the dataset 
"""

dataframes_path = '/content/drive/MyDrive/W281 Computer Vision/w281_final_project/kaggle_top_20_landmark_id_clean/pandas_exports/'

def load_dataset(file_name):
  return pd.read_pickle(f"{dataframes_path}{file_name}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load dataframes from pickle file -- uncomment the line to download the desire file
# Loads the top 20 dataset
main_dataset_df = load_dataset("top_20_df_w_images_arrays.pkl") 

# Loads the top 10 dataset
# main_dataset_df = load_dataset("top_10_df_w_images_arrays.pkl") 

# Loads the top 11 to 20 dataset
# main_dataset_df = load_dataset("top_11_to_20_df_w_images_arrays.pkl")

# %%
main_dataset_df.value_counts('category').sort_values(ascending=False)
# Out:
# category
# Khotyn_Fortress                            971
# Pe%C5%A1ter                                966
# Niagara_Falls                              944
# Haleakal%C4%81_National_Park               920
# Feroz_Shah_Kotla                           900
# Golden_Gate_Bridge                         888
# Grand_Canyon                               888
# Catedral_San_Sebasti%C3%A1n,_Cochabamba    888
# Madrid_R%C3%ADo                            861
# Kecharis                                   839
# Mathura_Museum                             820
# Hayravank_monastery                        820
# Qutb_Minar_and_its_monuments,_Delhi        776
# Sofiyivsky_Park                            757
# St._Lawrence,_Toronto                      754
# Akkerman_fortress                          742
# Edinburgh_Castle                           734
# Eiffel_Tower                               731
# Genoese_fortress_(Sudak)                   730
# Skopje_Fortress                            704
# ...

# %%
main_dataset_df.columns
# Out:
# Index(['id', 'landmark_id', 'category', 'tiny_image'], dtype='object')

# %%
# Plotting sample images
num_images = 8
fig, ax = plt.subplots(1,num_images, figsize=(40,8))
for i, ind in enumerate(main_dataset_df.index[:num_images]):
  ax[i].set_title(f"{main_dataset_df.landmark_id[ind]} - {main_dataset_df.category[ind]}")
  ax[i].axis('off')
  ax[i].imshow(main_dataset_df.tiny_image[ind])
plt.show()
